# %% [markdown]
# <a href="https://colab.research.google.com/github/Bkoome/cnn_model/blob/main/Untitled21.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
from tensorflow import keras
import matplotlib.pyplot as plt

# %%
IMAGESIZE=256
BATCHSIZE=32
EPOCH=50
N0_CLASSES=3
RGB_CHANNEL=3

# %%
image_dataset=tf.keras.preprocessing.image_dataset_from_directory(
    "/content/drive/MyDrive/potato_project/Training",
    shuffle=True,
    image_size=(IMAGESIZE,IMAGESIZE),
    batch_size=BATCHSIZE

)
# Out:
# Found 3251 files belonging to 3 classes.

# %%
class_name=image_dataset.class_names
class_name
# Out:
# ['Early_Blight', 'Healthy', 'Late_Blight']

# %%
len(image_dataset)
# Out:
# 102

# %%
for image_batch, label_batch in image_dataset.take(1):
  print(image_batch.shape)
  print(label_batch.numpy)
# Out:
# (32, 256, 256, 3)
# <bound method _EagerTensorBase.numpy of <tf.Tensor: shape=(32,), dtype=int32, numpy=
# array([0, 1, 1, 2, 1, 0, 2, 1, 1, 0, 0, 0, 2, 2, 1, 2, 0, 1, 0, 0, 0, 1,
#        0, 0, 1, 0, 1, 2, 0, 1, 2, 0], dtype=int32)>>

# %%
plt.figure(figsize=(10, 10))
for image_batch, label_batch in image_dataset.take(1):
    for i in range(32):
        ax = plt.subplot(8, 4, i+1)
        plt.imshow(image_batch[i].numpy().astype("uint8"))
        plt.title(class_name[label_batch[i]])
        plt.axis("off")

# %%
def get_dataset_partitions_tf(ds, train_split=0.8, validation_split=0.1, test_split=0.1, shuffle=True, shuffle_size=10000):
  assert (train_split + validation_split + test_split)==1
  ds_size=len(ds)
  if shuffle:
    ds=ds.shuffle(shuffle_size, seed=10)

  train_size=int(train_split*ds_size)
  validation_size=int(validation_split*ds_size)

  train_dataset=ds.take(train_size)
  validation_dataset=ds.take(validation_size)
  test_dataset=ds.skip(train_size).skip(validation_size)

  return train_dataset, validation_dataset, test_dataset

# %%
train_dataset, validation_dataset, test_dataset=get_dataset_partitions_tf(image_dataset)

# %%
len(train_dataset)
# Out:
# 81

# %%
len(validation_dataset)
# Out:
# 10

# %%
len(test_dataset)
# Out:
# 11

# %%
#cache, shuffle, prefetch
train_dataset=train_dataset.cache().shuffle(1000).prefetch(buffer_size=tf.data.AUTOTUNE)
validation_dataset=validation_dataset.cache().shuffle(1000).prefetch(buffer_size=tf.data.AUTOTUNE)
test_dataset=test_dataset.cache().shuffle(1000).prefetch(buffer_size=tf.data.AUTOTUNE)

# %%
resize_rescale = tf.keras.Sequential([
    tf.keras.layers.experimental.preprocessing.Resizing(IMAGESIZE, IMAGESIZE),
    tf.keras.layers.experimental.preprocessing.Rescaling(1./255)

])

# %%
data_augumentation=tf.keras.Sequential([
    tf.keras.layers.experimental.preprocessing.RandomFlip("horizontal_and_vertical"),
    tf.keras.layers.experimental.preprocessing.RandomRotation(0.2)
])

# %%
train_dataset=train_dataset.map(
    lambda x, y: (data_augumentation(x, training=True),y)
).prefetch(buffer_size=tf.data.AUTOTUNE)

# %%
model=tf.keras.models.Sequential([
    resize_rescale,
    data_augumentation,
    tf.keras.layers.Conv2D(32, kernel_size = (3,3), activation='relu', input_shape=(BATCHSIZE,IMAGESIZE, IMAGESIZE,RGB_CHANNEL)),
    tf.keras.layers.MaxPooling2D((2, 2)),
    tf.keras.layers.Conv2D(64,  kernel_size = (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D((2, 2)),
    tf.keras.layers.Conv2D(64,  kernel_size = (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D((2, 2)),
    tf.keras.layers.Conv2D(64, (3, 3), activation='relu'),
    tf.keras.layers.MaxPooling2D((2, 2)),
    tf.keras.layers.Conv2D(64, (3, 3), activation='relu'),
    tf.keras.layers.MaxPooling2D((2, 2)),
    tf.keras.layers.Conv2D(64, (3, 3), activation='relu'),
    tf.keras.layers.MaxPooling2D((2, 2)),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(64, activation="relu"),
    tf.keras.layers.Dense(N0_CLASSES, activation="softmax"), #normalize the probabiliy of the classes

])
model.build(input_shape=(BATCHSIZE,IMAGESIZE, IMAGESIZE, RGB_CHANNEL))

# %%
model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  sequential (Sequential)     (32, 256, 256, 3)         0
#
#  sequential_1 (Sequential)   (None, 256, 256, 3)       0
#
#  conv2d_6 (Conv2D)           (32, 254, 254, 32)        896
#
#  max_pooling2d_6 (MaxPoolin  (32, 127, 127, 32)        0
#  g2D)
#
#  conv2d_7 (Conv2D)           (32, 125, 125, 64)        18496
#
#  max_pooling2d_7 (MaxPoolin  (32, 62, 62, 64)          0
#  g2D)
#
#  conv2d_8 (Conv2D)           (32, 60, 60, 64)          36928
#
#  max_pooling2d_8 (MaxPoolin  (32, 30, 30, 64)          0
#  g2D)
#
#  conv2d_9 (Conv2D)           (32, 28, 28, 64)          36928
#
#  max_pooling2d_9 (MaxPoolin  (32, 14, 14, 64)          0
#  g2D)
#
#  conv2d_10 (Conv2D)          (32, 12, 12, 64)          36928
#
#  max_pooling2d_10 (MaxPooli  (32, 6, 6, 64)            0
#  ng2D)
#
# ...

# %%
model.compile(
    optimizer='adam',
    loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False),
    metrics=['accuracy']
)

# %%
fit_reference=model.fit(
    train_dataset,
    batch_size=BATCHSIZE,
    validation_data=validation_dataset,
    verbose=1,
    epochs=EPOCH

)
# Out:
# Epoch 1/50
#  5/81 [>.............................] - ETA: 4:18 - loss: 0.0619 - accuracy: 0.9812
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-39-5988cbc3d84b> in <cell line: 1>()
# ----> 1 fit_reference=model.fit(
#       2     train_dataset,
#       3     batch_size=BATCHSIZE,
#       4     validation_data=validation_dataset,
#       5     verbose=1,
#
# /usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      63         filtered_tb = None
#      64         try:
# ---> 65             return fn(*args, **kwargs)
#      66         except Exception as e:
#      67             filtered_tb = _process_traceback_frames(e.__traceback__)
#
# ...

# %%
accuracy=model.evaluate(test_dataset)
# Out:
# 11/11 [==============================] - 14s 573ms/step - loss: 0.0514 - accuracy: 0.9823

# %%
import numpy as np
for image_batch, label_batch in test_dataset.take(1):

    print("Image prediction ")
    plt.imshow(image_batch[0].numpy().astype('uint8'))
    print("Original label:",class_name[label_batch[0].numpy()])

    batch_prediction = model.predict(image_batch)
    print("predicted label:",class_name[np.argmax(batch_prediction[0])])
# Out:
# Image prediction
# Original label: Healthy
# 1/1 [==============================] - 0s 445ms/step
# predicted label: Healthy

# %%
acc = fit_reference.history['accuracy']
val_acc = fit_reference.history['val_accuracy']

loss = fit_reference.history['loss']
val_loss = fit_reference.history['val_loss']

# %%
plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(range(EPOCH), acc, label='Training Accuracy')
plt.plot(range(EPOCH), val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(range(EPOCH), loss, label='Training Loss')
plt.plot(range(EPOCH), val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
def predict(model, img):
    img_array = tf.keras.preprocessing.image.img_to_array(images[i].numpy())
    img_array = tf.expand_dims(img_array, 0)

    predictions = model.predict(img_array)

    predicted_class = class_names[np.argmax(predictions[0])]
    confidence = round(100 * (np.max(predictions[0])), 2)
    return predicted_class, confidence

# %%
from tensorflow.keras.models import load_model
model.save("/content/drive/MyDrive/Potato/model_1")
